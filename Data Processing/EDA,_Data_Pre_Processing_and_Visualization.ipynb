# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read dataset
df = pd.read_excel('/content/drive/MyDrive/Test dataset/data_set_tes_junior_engineer.xlsx')

# %%
df
# Out:
#             no_pesanan      kode_sku  \
# 0     220226GP3Y73KP_0  1.210102e+11
# 1     2202249WTG7191_0  1.210102e+11
# 2     2202249X4DS6UJ_0  1.210102e+11
# 3     220224AWVVSDVD_0  1.210102e+11
# 4     220225DXCVKH1B_0  1.210102e+11
# ...                ...           ...
# 3002  220227JJAQYVJ5_1  1.300000e+11
# 3003  220227JJAQYVJ5_0  1.300000e+11
# 3004  220227KF81M3V2_0  1.300000e+11
# 3005  220227KF81M3V2_1  1.300000e+11
# 3006      2081111112_0  1.200000e+11
#
#                                            nama_sku  qty  harga_awal  \
# 0           DAILYWEAR BANESKA PAJAMAS DANITA PINK L    1      239000
# 1     DAILYWEAR BANESKA PAJAMAS DEVITA BLUE ALLSIZE    1      209000
# 2     DAILYWEAR BANESKA PAJAMAS DEVITA BLUE ALLSIZE    1      209000
# 3     DAILYWEAR BANESKA PAJAMAS DEVITA BLUE ALLSIZE    1      209000
# 4     DAILYWEAR BANESKA PAJAMAS DEVITA BLUE ALLSIZE    1      209000
# ...                                             ...  ...         ...
# ...

# %%
#cek datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3007 entries, 0 to 3006
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   no_pesanan  3007 non-null   object
#  1   kode_sku    3006 non-null   float64
#  2   nama_sku    2977 non-null   object
#  3   qty         3007 non-null   int64
#  4   harga_awal  3007 non-null   int64
#  5   sumber      2397 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 141.1+ KB

# %%
df.describe(include = 'all')
# Out:
#           no_pesanan      kode_sku  \
# count   3.007000e+03  3.006000e+03
# unique  2.954000e+03           NaN
# top     2.070702e+09           NaN
# freq    6.000000e+00           NaN
# mean             NaN  1.294710e+11
# std              NaN  3.718126e+09
# min              NaN  1.200000e+11
# 25%              NaN  1.311101e+11
# 50%              NaN  1.311101e+11
# 75%              NaN  1.311101e+11
# max              NaN  1.311101e+11
#
#                                              nama_sku          qty  \
# count                                            2977  3007.000000
# unique                                            312          NaN
# top     HOMEWEAR ORIANA MAXI-DRESS CALLA NAVY ALLSIZE          NaN
# freq                                              173          NaN
# mean                                              NaN     1.011307
# std                                               NaN     0.138444
# ...

# %%
#cek number of unique
df.no_pesanan.nunique()
# Out:
# 2954

# %%
#cek row data
len(df.no_pesanan)
# Out:
# 3007

# %%
#cek duplicate
df['no_pesanan'].duplicated().sum()
# Out:
# 53

# %%
#cek null or NaN value
for col in df.columns:
  print("kolom : {} memiliki NaN value sebanyak \
  {} dari {} row".format(col, 
                         str(df[col].isna().sum()), 
                         str(len(df.index))))
# Out:
# kolom : no_pesanan memiliki NaN value sebanyak   0 dari 3007 row
# kolom : kode_sku memiliki NaN value sebanyak   1 dari 3007 row
# kolom : nama_sku memiliki NaN value sebanyak   30 dari 3007 row
# kolom : qty memiliki NaN value sebanyak   0 dari 3007 row
# kolom : harga_awal memiliki NaN value sebanyak   0 dari 3007 row
# kolom : sumber memiliki NaN value sebanyak   610 dari 3007 row

# %%
#mengisi data null pada kolom sumber
df['sumber'].fillna(value='LAZADA', inplace = True)

# %%
df.dropna(inplace = True) #drop null yang tersisa

# %%
df.duplicated(subset='no_pesanan').sum()
# Out:
# 53

# %%
df.drop_duplicates(subset='no_pesanan',inplace=True) #drop duplicated data

# %%
df.duplicated(subset='no_pesanan').sum()
# Out:
# 0

# %%
for col in df.columns:
  print("kolom : {} memiliki NaN value sebanyak \
  {} dari {} row".format(col, 
                         str(df[col].isna().sum()), 
                         str(len(df.index))))
# Out:
# kolom : no_pesanan memiliki NaN value sebanyak   0 dari 2924 row
# kolom : kode_sku memiliki NaN value sebanyak   0 dari 2924 row
# kolom : nama_sku memiliki NaN value sebanyak   0 dari 2924 row
# kolom : qty memiliki NaN value sebanyak   0 dari 2924 row
# kolom : harga_awal memiliki NaN value sebanyak   0 dari 2924 row
# kolom : sumber memiliki NaN value sebanyak   0 dari 2924 row

# %%
min(df['qty']) #cek minimum value
# Out:
# -1

# %%
df_no_min = df[df['qty'] >= 0] #filter data tanpa minus pada qty

# %%
min(df_no_min['qty'])
# Out:
# 1

# %%
df_no_min['total_harga'] = df_no_min['qty'] * df_no_min['harga_awal'] #membuat kolom baru total harga
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_no_min[df['qty']>1] #cek data
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#             no_pesanan      kode_sku  \
# 19    220225D8UVQHCC_0  1.210102e+11
# 139       2069593313_0  1.210102e+11
# 144       2075800101_0  1.210102e+11
# 147       2072629482_0  1.210102e+11
# 325   2202225RXAP43Y_3  1.311101e+11
# 393   220225DT2HBX2V_0  1.311101e+11
# 400       2081154601_1  1.311101e+11
# 412   2202214BB7Y0XX_2  1.311101e+11
# 474   220227K6KHNMBS_0  1.311101e+11
# 518   220225DRMH8FV6_0  1.311101e+11
# 519   220225DRNFJJUG_0  1.311101e+11
# 641   220225DPCMSXF9_0  1.311101e+11
# 833   220225CXMBR29P_0  1.311101e+11
# 877   2202238DTJQJEW_0  1.311101e+11
# 1022      2080463190_2  1.311101e+11
# 1043      2080463190_1  1.311101e+11
# 1099      2084578780_0  1.311101e+11
# 1133  220225DRHXVFQ9_0  1.311101e+11
# 1134  220225DRJYC93K_0  1.311101e+11
# ...

# %%
df_no_min #cek hasil akhir
# Out:
#             no_pesanan      kode_sku  \
# 0     220226GP3Y73KP_0  1.210102e+11
# 1     2202249WTG7191_0  1.210102e+11
# 2     2202249X4DS6UJ_0  1.210102e+11
# 3     220224AWVVSDVD_0  1.210102e+11
# 4     220225DXCVKH1B_0  1.210102e+11
# ...                ...           ...
# 2972  220225E3VEFE0S_0  1.210102e+11
# 2973  2202237U8KS40J_0  1.210102e+11
# 2974  220225EGCFYH7A_0  1.210102e+11
# 2975  220226EQ8TDPVR_1  1.210102e+11
# 2976  220227HN96VDSH_4  1.210102e+11
#
#                                            nama_sku  qty  harga_awal  sumber  \
# 0           DAILYWEAR BANESKA PAJAMAS DANITA PINK L    1      239000  SHOPEE
# 1     DAILYWEAR BANESKA PAJAMAS DEVITA BLUE ALLSIZE    1      209000  SHOPEE
# 2     DAILYWEAR BANESKA PAJAMAS DEVITA BLUE ALLSIZE    1      209000  SHOPEE
# 3     DAILYWEAR BANESKA PAJAMAS DEVITA BLUE ALLSIZE    1      209000  SHOPEE
# 4     DAILYWEAR BANESKA PAJAMAS DEVITA BLUE ALLSIZE    1      209000  SHOPEE
# ...

# %%
df_sku = df_no_min[['nama_sku','qty','total_harga']].groupby(by='nama_sku').sum() #aggregasi data

# %%
df_sku
# Out:
#                                                 qty  total_harga
# nama_sku
# DAILYWEAR BANESKA PAJAMAS DANITA PINK L           1       239000
# DAILYWEAR BANESKA PAJAMAS DEVITA BLUE ALLSIZE     4       836000
# DAILYWEAR BANESKA PAJAMAS DEVITA KHAKI ALLSIZE    4       836000
# DAILYWEAR BANESKA PAJAMAS DEVITA PINK ALLSIZE     1       209000
# DAILYWEAR BANESKA PAJAMAS ELSA BLACK L            7      1673000
# ...                                             ...          ...
# MUSLIMWEAR BANESKA GAMIS-PREMIUM NISA SKY M       1       299000
# MUSLIMWEAR BANESKA GAMIS-PREMIUM TIARA NAVY M     1       299000
# MUSLIMWEAR BANESKA TUNIK DIANA MINT S-M           1       239000
# MUSLIMWEAR BANESKA TUNIK FIONA GREEN L-XL         1       239000
# MUSLIMWEAR BANESKA TUNIK FIONA NAVY L-XL          2       478000
#
# [310 rows x 2 columns]

# %%
df_sku_sorted = df_sku.sort_values(by='qty',axis=0,ascending=False)

# %%
df_sku_sorted.head(10) #cek top 10 produk
# Out:
#                                                     qty  total_harga
# nama_sku
# HOMEWEAR ORIANA MAXI-DRESS CALLA NAVY ALLSIZE       171     23256990
# HOMEWEAR ORIANA MAXI-DRESS CALLA LILAC ALLSIZE      115     15959547
# HOMEWEAR ORIANA KAFTAN HAZEL GREY ALLSIZE           111     12166072
# HOMEWEAR ORIANA MAXI-DRESS GARDENIA NAVY ALLSIZE    106     13002271
# HOMEWEAR ORIANA MAXI-DRESS CALLA MINT ALLSIZE        73     11043100
# HOMEWEAR ORIANA MAXI-DRESS GARDENIA GREEN ALLSIZE    71      8975357
# HOMEWEAR ORIANA MAXI-DRESS GARDENIA MAROON ALLSIZE   69      8160314
# HOMEWEAR ORIANA KAFTAN HAZEL MINT ALLSIZE            63      9071555
# HOMEWEAR ORIANA KAFTAN DAISY BLUE ALLSIZE            57      8121500
# HOMEWEAR ORIANA MAXI-DRESS ANAYA PURPLE ALLSIZE      56      7210363

# %%
#Cek Jumlah perbanding sumber
plt.figure(figsize=[10,10])
sns.countplot(df_no_min['sumber']).set_title('Performa Sumber')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# Text(0.5, 1.0, 'Performa Sumber')

# %%
#visualisasi Top 10 Product
plt.figure(figsize=[10,10])
sns.barplot(x='qty',y=df_sku_sorted.head(10).index,data=df_sku_sorted.head(10)).set_title('TOP 10 SKU Paling Banyak Terjual')
# Out:
# Text(0.5, 1.0, 'TOP 10 SKU Paling Banyak Terjual')

# %%
df_sumber = df_no_min.groupby(by=['nama_sku','sumber'], as_index=False).sum().sort_values(by='qty',axis=0,ascending=False) #Aggregasi data

# %%
#TOP 3 Product pada setiap sumber
df_sumber.groupby('sumber').head(3)
# Out:
#                                              nama_sku     sumber  \
# 283     HOMEWEAR ORIANA MAXI-DRESS CALLA NAVY ALLSIZE     SHOPEE
# 276    HOMEWEAR ORIANA MAXI-DRESS CALLA LILAC ALLSIZE     SHOPEE
# 303  HOMEWEAR ORIANA MAXI-DRESS GARDENIA NAVY ALLSIZE     SHOPEE
# 138         HOMEWEAR ORIANA KAFTAN HAZEL GREY ALLSIZE     LAZADA
# 302  HOMEWEAR ORIANA MAXI-DRESS GARDENIA NAVY ALLSIZE     LAZADA
# 282     HOMEWEAR ORIANA MAXI-DRESS CALLA NAVY ALLSIZE     LAZADA
# 277    HOMEWEAR ORIANA MAXI-DRESS CALLA LILAC ALLSIZE  TOKOPEDIA
# 160    HOMEWEAR ORIANA KAFTAN LILIBELLE PEACH ALLSIZE  TOKOPEDIA
# 140         HOMEWEAR ORIANA KAFTAN HAZEL GREY ALLSIZE  TOKOPEDIA
# 141         HOMEWEAR ORIANA KAFTAN HAZEL GREY ALLSIZE    WEBSITE
# 157     HOMEWEAR ORIANA KAFTAN LILIBELLE MINT ALLSIZE    WEBSITE
# 145         HOMEWEAR ORIANA KAFTAN HAZEL MINT ALLSIZE    WEBSITE
#
#          kode_sku  qty  harga_awal  total_harga
# 283  1.547099e+13  118    17582000     17582000
# ...
